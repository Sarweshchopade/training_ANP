# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarweshchopade/training_ANP/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program to create a NumPy array with five integers and display it.
#
# -->

# %%
import numpy as np
arr=np.array([10, 20, 30, 40, 50])
print("NumPy Array:", arr)
# Out:
# NumPy Array: [10 20 30 40 50]

# %% [markdown]
# Write a program to find the data type of a NumPy array.
#
# -->

# %%
import numpy as np
arr=np.array([1, 2, 3, 4, 5])
print("Data type of the NumPy array:", arr.dtype)
# Out:
# Data type of the NumPy array: int64

# %% [markdown]
# Write a program to access the first and last element of a NumPy array.
#
# -->

# %%
import numpy as np
arr=np.array([10, 20, 30, 40, 50])
print("First element:", arr[0])
print("Last element:", arr[-1])
# Out:
# First element: 10
# Last element: 50

# %% [markdown]
# Write a program to slice a NumPy array and print elements from index 1 to 3.
#
# -->

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
print("Elements from index 1 to 3:", arr[1:4])
# Out:
# Elements from index 1 to 3: [20 30 40]

# %% [markdown]
# Write a program to display the first three elements of a NumPy array using slicing.
#
# -->

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
print("First three elements:", arr[:3])
# Out:
# First three elements: [10 20 30]

# %% [markdown]
# Write a program to extract the last two elements of a NumPy array using slicing.
#
# -->

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
print("Last two elements:", arr[-2:])
# Out:
# Last two elements: [40 50]
