# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarweshchopade/training_ANP/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=[]
for i in range(5):
    marks.append(int(input("Enter mark: ")))
print("Student marks:", marks)
# Out:
# Enter mark: 89
# Enter mark: 76
# Enter mark: 56
# Enter mark: 77
# Enter mark: 80
# Student marks: [89, 76, 56, 77, 80]

# %%
numbers=[12, 45, 23, 89, 34]
print("Largest number:", max(numbers))
# Out:
# Largest number: 89

# %%
numbers=[1, 2, 3, 2, 4, 2, 5]
element=int(input("Enter element to count: "))
print("Count:", numbers.count(element))
# Out:
# Enter element to count: 2
# Count: 3

# %%
lst=[10, 20, 30, 40]
lst.append(50)     # add
lst.remove(20)     # remove
print("Updated list:", lst)
# Out:
# Updated list: [10, 30, 40, 50]

# %%
numbers=[10, 20, 30, 40]
print("Sum:", sum(numbers))
# Out:
# Sum: 100

# %%
t=(10, 20, 30, 40, 50)
print("Second element:", t[1])
# Out:
# Second element: 20

# %%
t=(5, 10, 15, 20)
x=int(input("Enter element: "))
if x in t:
    print("Element exists")
else:
    print("Element does not exist")
# Out:
# Enter element: 10
# Element exists

# %%
t=(1, 2, 3, 4)
lst=list(t)
print("List:", lst)
# Out:
# List: [1, 2, 3, 4]

# %%
t=(10, 20, 30, 40)
print("Length of tuple:", len(t))
# Out:
# Length of tuple: 4

# %%
student={"name": "Rahul", "roll_no": 101, "marks": 85}
print(student)
# Out:
# {'name': 'Rahul', 'roll_no': 101, 'marks': 85}

# %%
student={"name": "Rahul", "marks": 85}
student["age"]=20
print(student)
# Out:
# {'name': 'Rahul', 'marks': 85, 'age': 20}

# %%
student={"name": "Rahul", "marks": 85}
student["marks"]=90
print(student)
# Out:
# {'name': 'Rahul', 'marks': 90}

# %%
student={"name": "Rahul", "marks": 85}
if "marks" in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Key exists

# %%
student={"name": "Rahul", "marks": 85}
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Rahul
# marks : 85

# %%
s={1, 2, 3, 2, 4, 3}
print("Set:", s)
# Out:
# Set: {1, 2, 3, 4}

# %%
s={1, 2, 3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s={1, 2, 3}
s.remove(2)
print(s)
# Out:
# {1, 3}

# %%
a={1, 2, 3}
b={3, 4, 5}
print("Union:", a.union(b))
# Out:
# Union: {1, 2, 3, 4, 5}

# %%
a={1, 2, 3}
b={3, 4, 5}
print("Intersection:", a.intersection(b))
# Out:
# Intersection: {3}
