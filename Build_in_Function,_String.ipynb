# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarweshchopade/training_ANP/blob/main/Build_in_Function%2C_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=input("Enter string:")
print("Length:", len(s))
# Out:
# Enter string:afjbihf
# Length: 7

# %%
num=input("Enter a number: ")
print("Data type:", type(num))
# Out:
# Enter a number: 4
# Data type: <class 'str'>

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
print("Sum:", a+b)
# Out:
# Enter first number: 5
# Enter second number: 3
# Sum: 8

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
print("Maximum:", max(a,b))
# Out:
# Enter first number: 12
# Enter second number: 5
# Maximum: 12

# %%
s=input("Enter a string: ")
print(s.upper())
# Out:
# Enter a string: happy
# HAPPY

# %%
s=input("Enter a string:")
if len(s)>0:
    print("First character:", s[0])
    print("Last character:", s[-1])
# Out:
# Enter a string:happy
# First character: h
# Last character: y

# %%
s=input("Enter a string: ")
if s=="":
    print("String is empty")
else:
    print("String is not empty")
# Out:
# Enter a string: happy
# String is not empty

# %%
s=input("Enter a string: ")
count=0
for ch in s:
    count+=1
print("Number of characters:", count)
# Out:
# Enter a string: happy
# Number of characters: 5

# %%
s=input("Enter a string: ")
print("Reversed string:", s[::-1])
# Out:
# Enter a string: happy
# Reversed string: yppah

# %%
s=input("Enter a string: ")
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: hah
# Palindrome

# %%
s=input("Enter a string: ")
print("Lowercase:", s.lower())
print("Uppercase:", s.upper())
# Out:
# Enter a string: happy
# Lowercase: happy
# Uppercase: HAPPY

# %%
s=input("Enter a string:")
print("After strip:", s.strip())
# Out:
# Enter a string:happy
# After strip: happy

# %%
s=input("Enter a sentence:")
old=input("Word to replace:")
new=input("New word:")
print("Updated sentence:", s.replace(old, new))
# Out:
# Enter a sentence:happy
# Word to replace:awesome
# New word:ssss
# Updated sentence: happy

# %%
s=input("Enter a sentence: ")
word=input("Enter word to find: ")
pos=s.find(word)
if pos!=-1:
    print("Word found at position:", pos)
else:
    print("Word not found")
# Out:
# Enter a sentence: i am happy
# Enter word to find: am
# Word found at position: 2

# %%
s=input("Enter a sentence: ")
words=s.split()
print(words)
# Out:
# Enter a sentence: i am happy
# ['i', 'am', 'happy']

# %%
name=input("Enter username: ")
name=name.replace(" ", "")
print("Total characters:", len(name))
# Out:
# Enter username: sarwesh
# Total characters: 7

# %%
email=input("Enter email ID:")
if "@" in email:
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Enter email ID:sarwesh@gmail.com
# Valid email

# %%
s=input("Enter a string: ")
count=0
for ch in s.lower():
    if ch in "aeiou":
        count+=1
print("Number of vowels:", count)
# Out:
# Enter a string: happy
# Number of vowels: 1

# %%
s=input("Enter a sentence: ")
words=s.split()
print("Number of words:", len(words))
# Out:
# Enter a sentence: i am happy
# Number of words: 3

# %%
s=input("Enter a string:")
for ch in s:
    print(ch)
# Out:
# Enter a string:happy
# h
# a
# p
# p
# y
